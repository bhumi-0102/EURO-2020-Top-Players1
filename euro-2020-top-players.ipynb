# %% [markdown]
# # EURO-2020 TOP PLAYERS

# %% [markdown]
# The 2020 UEFA European Football Championship, commonly referred to as UEFA Euro 2020 or simply Euro 2020, was the 16th UEFA European Championship, the quadrennial international men's football championship of Europe organised by the Union of European Football Associations (UEFA). To celebrate the 60th anniversary of the European Championship competition, UEFA president Michel Platini declared that the tournament would be hosted in several nations as a "romantic" one-off event, with 11 cities in 11 UEFA countries each providing venues for the tournament. Defending champions Portugal, who won Euro 2016 in France, were eliminated in the round of 16 by Belgium. Italy won their second European Championship title by beating England on penalties in the final following a 1–1 draw after extra time.
#
# Due to the COVID-19 pandemic in Europe during 2020, the tournament was postponed to summer 2021,while retaining the name UEFA Euro 2020 and host venues. Alongside special rules regarding COVID-19, UEFA also allowed more substitutions and implemented video assistant referee (VAR) for the first time.
#
# Initially, 13 venues were chosen for the tournament but two were later dropped. Brussels was dropped in December 2017 after the building of the city's Eurostadium was abandoned, while Dublin was dropped in April 2021 because there was no guarantee that spectators could attend. Spain originally intended to use Bilbao as a host venue but later changed it to Seville to allow for spectators at matches. UEFA chose Stadio Olimpico in Rome to host the opening match between Italy and Turkey, while Wembley Stadium in London was selected as a semi-final and final venue for the second time, following the 1996 tournament at the original stadium.
#
# The tournament was well-received by fans and commentators, with the most goals per game in a European Championship since the introduction of the group stage, and only two goalless games. The refereeing style was also praised, with a conservative use of VAR and quick decisions made on the pitch. Belgium, France, and Sweden lost to lower-ranked sides.

# %% [markdown]
# ### How to run the code
#
# This is an executable [*Jupyter notebook*](https://jupyter.org) hosted on [Jovian.ml](https://www.jovian.ml), a platform for sharing data science projects. You can run and experiment with the code in a couple of ways: *using free online resources* (recommended) or *on your own computer*.
#
# #### Option 1: Running using free online resources (1-click, recommended)
#
# The easiest way to start executing this notebook is to click the "Run" button at the top of this page, and select "Run on Binder". This will run the notebook on [mybinder.org](https://mybinder.org), a free online service for running Jupyter notebooks. You can also select "Run on Colab" or "Run on Kaggle".
#
#
# #### Option 2: Running on your computer locally
#
# 1. Install Conda by [following these instructions](https://conda.io/projects/conda/en/latest/user-guide/install/index.html). Add Conda binaries to your system `PATH`, so you can use the `conda` command on your terminal.
#
# 2. Create a Conda environment and install the required libraries by running these commands on the terminal:
#
# ```
# conda create -n zerotopandas -y python=3.8
# conda activate zerotopandas
# pip install jovian jupyter numpy pandas matplotlib seaborn opendatasets --upgrade
# ```
#
# 3. Press the "Clone" button above to copy the command for downloading the notebook, and run it on the terminal. This will create a new directory and download the notebook. The command will look something like this:
#
# ```
# jovian clone notebook-owner/notebook-id
# ```
#
#
#
# 4. Enter the newly created directory using `cd directory-name` and start the Jupyter notebook.
#
# ```
# jupyter notebook
# ```
#
# You can now access Jupyter's web interface by clicking the link that shows up on the terminal or by visiting http://localhost:8888 on your browser. Click on the notebook file (it has a `.ipynb` extension) to open it.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import matplotlib

# %%
euro_df = pd.read_csv('./euro2020.csv')

# %%
euro_df.head()
# Out:
#               Player         Country Position  Match played  Goals  \
# 0  Cristiano Ronaldo        Portugal        F             4      5
# 1      Patrik Schick  Czech Republic        F             5      5
# 2      Karim Benzema          France        F             4      4
# 3      Emil Forsberg          Sweden        M             4      4
# 4      Romelu Lukaku         Belgium        F             5      4
#
#    Right foot goals  Left foot goals  Header goals  Assists  Total attempts  \
# 0               3.0              2.0           0.0      1.0            16.0
# 1               1.0              3.0           1.0      0.0            16.0
# 2               2.0              2.0           1.0      0.0            11.0
# 3               2.0              2.0           0.0      0.0            14.0
# 4               2.0              2.0           0.0      0.0            13.0
#
#    ...  Top speed  Passing accuracy  Distance covered  Clearence attempted  \
# ...

# %%
project_name = "zerotopandas-course-project-euro2020"

# %%
# !pip install jovian --upgrade --quiet

# %%
import jovian

# %%
# Execute this to save new versions of the notebook
jovian.commit(project="euro-2020-top-players")
# Out:
# [jovian] Updating notebook "karakotibhumika2000/euro-2020-top-players" on https://jovian.ai
# [jovian] Committed successfully! https://jovian.ai/karakotibhumika2000/euro-2020-top-players
# 'https://jovian.ai/karakotibhumika2000/euro-2020-top-players'

# %% [markdown]
# ## Data Preparation and Cleaning

# %% [markdown]
# Load the dataset into a data frame using Pandas

# %% [markdown]
# Columns:
#
# Player: Name of the player .
#
# Country: Players country
#
# Position: Where the player play Match played: How many match played
#
# Goals: How many goals scored
#
# Right foot goals: How many goals scored by right foot
#
# Header goals: How many goals scored by head
#
# Assists: Number of assists
#
# Total attempts: Total attempts on goal
#
# On target: Total attempts on target
#
# Off target: Total attempts off target
#
# Woodwork: Total attempts hit the post
#
# Shot blocks: Number of shot blocked by defender
#
# Avg gpg: Average goals per game
#
# Fouls suffered: Total fouls suffered
#
# Fouls committed: Total fouls committed
#
# Top speed: Top speed
#
# Passing accuracy: Passing accuracy
#
# Distance covered: Total distance covered
#
# Clearence attempted: Total attempts of clearing the ball
#
# Balls recovered: Total balls recovered
#
# Tackles: Total tackles
#
# Blocks: Total shot blocked
#
# Yellow cards: Total yellow cards
#
# Red cards: Total red cards
#
# Minutes played: Total minutes played

# %%
euro_df.describe()
# Out:
#        Match played      Goals  Right foot goals  Left foot goals  \
# count     59.000000  59.000000         57.000000        57.000000
# mean       4.813559   1.338983          0.649123         0.456140
# std        1.166701   1.504134          0.876096         0.757585
# min        2.000000   0.000000          0.000000         0.000000
# 25%        4.000000   0.000000          0.000000         0.000000
# 50%        4.000000   1.000000          0.000000         0.000000
# 75%        6.000000   2.000000          1.000000         1.000000
# max        7.000000   5.000000          3.000000         3.000000
#
#        Header goals    Assists  Total attempts  On target  Off target  \
# count     57.000000  58.000000       58.000000  56.000000   56.000000
# mean       0.210526   0.741379        7.620690   2.982143    2.982143
# std        0.490511   1.018433        5.634566   2.673038    2.576051
# min        0.000000   0.000000        0.000000   0.000000    0.000000
# ...

# %%
euro_df.shape
# Out:
# (59, 27)

# %%
euro_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Player               59 non-null     object
#  1   Country              59 non-null     object
#  2   Position             58 non-null     object
#  3   Match played         59 non-null     int64
#  4   Goals                59 non-null     int64
#  5   Right foot goals     57 non-null     float64
#  6   Left foot goals      57 non-null     float64
#  7   Header goals         57 non-null     float64
#  8   Assists              58 non-null     float64
#  9   Total attempts       58 non-null     float64
#  10  On target            56 non-null     float64
#  11  Off target           56 non-null     float64
#  12  Woodwork             55 non-null     float64
#  13  Shot blocks          56 non-null     float64
#  14  Avg gpg              59 non-null     float64
# ...

# %%
euro_df.nunique()
# Out:
# Player                 59
# Country                18
# Position                3
# Match played            6
# Goals                   6
# Right foot goals        4
# Left foot goals         4
# Header goals            3
# Assists                 5
# Total attempts         21
# On target              10
# Off target              9
# Woodwork                3
# Shot blocks             7
# Avg gpg                17
# Fouls suffered         16
# Fouls committed        13
# Top speed              27
# Passing accuracy       25
# Distance covered       55
# Clearence attempted    17
# Balls recovered        33
# Tackels                14
# Blocks                  6
# Yellow cards            4
# Red cards               1
# Minutes played         45
# dtype: int64

# %% [markdown]
# # Handling Null Values

# %%
euro_df.isnull().values.any()
# Out:
# True

# %%
euro_df.isnull().sum()
# Out:
# Player                  0
# Country                 0
# Position                1
# Match played            0
# Goals                   0
# Right foot goals        2
# Left foot goals         2
# Header goals            2
# Assists                 1
# Total attempts          1
# On target               3
# Off target              3
# Woodwork                4
# Shot blocks             3
# Avg gpg                 0
# Fouls suffered          4
# Fouls committed         0
# Top speed               0
# Passing accuracy        0
# Distance covered        0
# Clearence attempted     9
# Balls recovered         4
# Tackels                 6
# Blocks                 40
# Yellow cards            3
# Red cards               3
# Minutes played          0
# dtype: int64

# %%
euro_df.isnull().sum().sum()
# Out:
# 91

# %%
euro_df['Position'].fillna('No Position', inplace=True)
euro_df['Right foot goals'].fillna('No Right foot goals', inplace=True)
euro_df['Left foot goals'].fillna('No Left foot goals', inplace=True)
euro_df['Header goals'].fillna('No Header goals', inplace=True)
euro_df['Assists'].fillna('No Assists', inplace=True)
euro_df['Total attempts'].fillna('No Total attempts', inplace=True)
euro_df['On target'].fillna('No On target', inplace=True)
euro_df['Off target'].fillna('No Off target', inplace=True)
euro_df['Woodwork'].fillna('No Woodwork', inplace=True)
euro_df['Shot blocks'].fillna('No Shot blocks', inplace=True)
euro_df['Fouls suffered'].fillna('No Fouls suffered', inplace=True)
euro_df['Clearence attempted'].fillna('No Clearence attempted', inplace=True)
euro_df['Fouls suffered'].fillna('No Fouls suffered', inplace=True)
euro_df['Balls recovered'].fillna('No Balls recovered', inplace=True)
euro_df['Tackels'].fillna('No Tackels', inplace=True)
euro_df['Yellow cards'].fillna('No Yellow cards', inplace=True)
euro_df['Yellow cards'].fillna('No Yellow cards', inplace=True)
euro_df['Red cards'].fillna('No Red cards', inplace=True)

# %%
euro_df.drop('Blocks', inplace=True, axis=1)

# %%
euro_df.isnull().any()
# Out:
# Player                 False
# Country                False
# Position               False
# Match played           False
# Goals                  False
# Right foot goals       False
# Left foot goals        False
# Header goals           False
# Assists                False
# Total attempts         False
# On target              False
# Off target             False
# Woodwork               False
# Shot blocks            False
# Avg gpg                False
# Fouls suffered         False
# Fouls committed        False
# Top speed              False
# Passing accuracy       False
# Distance covered       False
# Clearence attempted    False
# Balls recovered        False
# Tackels                False
# Yellow cards           False
# Red cards              False
# Minutes played         False
# dtype: bool

# %%
euro_df.head()
# Out:
#               Player         Country Position  Match played  Goals  \
# 0  Cristiano Ronaldo        Portugal        F             4      5
# 1      Patrik Schick  Czech Republic        F             5      5
# 2      Karim Benzema          France        F             4      4
# 3      Emil Forsberg          Sweden        M             4      4
# 4      Romelu Lukaku         Belgium        F             5      4
#
#   Right foot goals Left foot goals Header goals Assists Total attempts  ...  \
# 0              3.0             2.0          0.0     1.0           16.0  ...
# 1              1.0             3.0          1.0     0.0           16.0  ...
# 2              2.0             2.0          1.0     0.0           11.0  ...
# 3              2.0             2.0          0.0     0.0           14.0  ...
# 4              2.0             2.0          0.0     0.0           13.0  ...
#
#   Fouls committed Top speed Passing accuracy Distance covered  \
# ...

# %%
import jovian

# %%
jovian.commit()

# %% [markdown]
# ## Exploratory Analysis and Visualization
#
# First we will begin analysis on the entire Amazon prime dataset consisting of Tv shows. Revisiting the data, We will analyse about some of the details in the dataset and conclude some important analysis found out in our observations.

# %%
sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
euro_df.describe()
# Here we will examine the mean values and the standard deviation value of our dataset.
# I will use it again in the future.
# Out:
#        Match played      Goals    Avg gpg  Fouls committed  Top speed  \
# count     59.000000  59.000000  59.000000        59.000000  59.000000
# mean       4.813559   1.338983   0.282881         4.864407  30.327119
# std        1.166701   1.504134   0.335374         2.849426   1.560927
# min        2.000000   0.000000   0.000000         0.000000  26.600000
# 25%        4.000000   0.000000   0.000000         3.000000  29.500000
# 50%        4.000000   1.000000   0.200000         5.000000  30.600000
# 75%        6.000000   2.000000   0.500000         6.500000  31.400000
# max        7.000000   5.000000   1.250000        12.000000  33.100000
#
#        Passing accuracy  Distance covered  Minutes played
# count         59.000000         59.000000       59.000000
# mean          83.711864         46.272881      417.796610
# std            7.714855         14.160421      122.439961
# min           66.000000         18.100000      180.000000
# ...

# %% [markdown]
# #### Here I will evaluate the data by dividing it into 2.
#
# #### I will divide it as a country game and an individual game.
#
# ### THE TEAM İSTATİSTİC
#
# #### Here we will consider the data as countries.
#
# ### Team general statistics.

# %% [markdown]
# ### value_counts----->>>
# #### Return a Series containing counts of unique values.
#
# The resulting object will be in descending order so that the first element is the most frequently-occurring element. Excludes NA values by default.

# %%
countrys =euro_df.Country.value_counts().index
# ['England', 'Italy', 'Spain', 'France', 'Germany', 'Portugal', 'Belgium','Denmark', 'Switzerland', 'Wales', 'Netherlands', 'Ukraine', 'Austria','Croatia', 'Czech Republic', 'SwitzerlandF', 'Sweden', 'Poland']

values=euro_df.Country.value_counts().values
#[7, 7, 5, 5, 5, 5, 4, 4, 2, 2, 2, 2, 2, 2, 2, 1, 1, 1]
  
# Creating plot
fig = plt.figure(figsize =(10, 7))
plt.pie(values, labels = countrys)
  
# show plot
plt.show()

# %% [markdown]
# # Number of goals scored by country.

# %%
country_goals=[]
for a in countrys:
    country_goals.append(sum(euro_df.Goals[euro_df.Country==a]))

plt.figure(figsize=(15,10))
sns.barplot(x=countrys, y=country_goals)
plt.xticks(rotation= 45)
plt.xlabel('countrys')
plt.ylabel('goals')
plt.title('total number of goals by countries')
# Out:
# Text(0.5, 1.0, 'total number of goals by countries')

# %% [markdown]
# # Number of players by position played.

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=euro_df['Position'].value_counts().index, y=euro_df['Position'].value_counts().values)
plt.xticks(rotation= 45)
plt.xlabel('position')
plt.ylabel('number of player')
plt.title('football player and position chart .')
# Out:
# Text(0.5, 1.0, 'football player and position chart .')

# %%
country1 = euro_df[euro_df.Country != 'No Country'].set_index('Match played').Country.str.split(', ', expand=True).stack().reset_index(level=1, drop=True)
sns.countplot(y = country1, order=country1.value_counts().index[:18])
plt.show()

# %%
euro_df['Country'].unique()
# Out:
# array(['Portugal', 'Czech Republic', 'France', 'Sweden', 'Belgium',
#        'England', 'Switzerland', 'Denmark', 'Poland', 'Netherlands',
#        'Spain', 'SwitzerlandF', 'Italy', 'Ukraine', 'Germany', 'Austria',
#        'Croatia', 'Wales'], dtype=object)

# %% [markdown]
# # match counts

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=euro_df.Player, y=euro_df["Match played"])
plt.xticks(rotation= 90)
plt.xlabel('Players')
plt.ylabel('number of matches played.')
plt.title("Players-number of matches played")
# Out:
# Text(0.5, 1.0, 'Players-number of matches played')

# %% [markdown]
# # Let's print top players with word cloud

# %%
pip install wordcloud
# Out:
# ...
#      |████████████████████████████████| 363 kB 5.9 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud, STOPWORDS
players=euro_df.Player
plt.subplots(figsize=(8,8))
wordcloud = WordCloud(
     background_color='white',
                          width=1000,
                          height=1000
                         ).generate(" ".join(players))
                         
plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('graph.png')

plt.show()

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "karakotibhumika2000/euro-2020-top-players" on https://jovian.ai
# [jovian] Committed successfully! https://jovian.ai/karakotibhumika2000/euro-2020-top-players
# 'https://jovian.ai/karakotibhumika2000/euro-2020-top-players'
